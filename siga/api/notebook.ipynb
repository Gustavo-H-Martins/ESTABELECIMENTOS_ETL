# %%
from request_siga_api import get_siga

base = get_siga()

# %%
import pandas as pd
dados = pd.DataFrame(base)

# %%
dados["ASSOCIADO"].value_counts()
# Out:
# ASSOCIADO
# INATIVO    15437
# ATIVO      15119
# Name: count, dtype: int64

# %%
duplicados = dados[dados['CNPJ'].duplicated() == True]
duplicados.sort_values(by=['CNPJ'], ascending=True, inplace=True)
duplicados.reset_index()
duplicados
# Out:
# C:\Users\ABRASEL NACIONAL\AppData\Local\Temp\ipykernel_16548\3774195028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicados.sort_values(by=['CNPJ'], ascending=True, inplace=True)
#                      SEC_REG                       NOME_FANTASIA
# 10335    RIO GRANDE DO NORTE                                MOOD  \
# 12817               NORTE PR                                JOÃO
# 12946            NOROESTE PR             ESCRITÓRIO DE ADVOCACIA
# 5827               SÃO PAULO                      ROBERTA COELHO
# 5736               SÃO PAULO                                 OTO
# ...                      ...                                 ...
# 12760               NORTE PR  LA FRANCINE´S BUFFET & RESTAURANTE
# 14530  REGIÃO DE CAMPINAS SP             BARBA BAR E RESTAURANTE
# ...

# %%
duplicados.to_excel('./SIGA_DUPLICADOS_CNPJ.xlsx',sheet_name="CNPJs DUPLICADOS NO SIGA", index=False)
