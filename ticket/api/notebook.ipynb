# %% [markdown]
# ``` JSON TICKET
# [{'id': '08248008000183',
# 'razaoSocial': 'LCAFETERIA ANALUMA LTDA ME',
# 'nomeEstabelecimento': 'CYBER CAFE',
# 'endereco': 'AV ALVARES CABRAL, 1830',
# 'bairro': 'LOURDES',
# 'cidade': 'BELO HORIZONTE',
# 'estado': 'MG',
# 'cep': '30170001',
# 'telefone': '30196726',
# 'latitude': -19.93332862854004,
# 'longitude': -43.95136642456055,
# 'distanciaMetros': 3444},
# {'id': '27878392000142',
# 'razaoSocial': 'ALINE REIS DE SOUZA 09285495699',
# 'nomeEstabelecimento': 'CANDY ATELIE',
# 'endereco': 'AV ALVARES CABRAL, 1830',
# 'bairro': 'SANTO AGOSTINHO',
# 'cidade': 'BELO HORIZONTE',
# 'estado': 'MG',
# 'cep': '30170008',
# 'telefone': '996928080',
# 'latitude': -19.93332862854004,
# 'longitude': -43.95136642456055,
# 'distanciaMetros': 3444}]
# ```

# %%
from resquest_ticket_api import *

base = get_ticket()
base
# Out:
# [{'CNPJ': '18836538000104',
#   'RAZAO_SOCIAL': 'MARILDA MARTINS SILVA 95449752687',
#   'ESTABELECIMENTO': 'CANTINA DA MARILDA',
#   'ENDERECO': 'R POUSO ALTO, 727',
#   'BAIRRO': 'SERRA',
#   'CIDADE': 'BELO HORIZONTE',
#   'UF': 'MG',
#   'CEP': '30240180',
#   'TELEFONE': '986449681',
#   'LATITUDE': -19.93463134765625,
#   'LONGITUDE': -43.91831970214844},
#  {'CNPJ': '00112154000175',
#   'RAZAO_SOCIAL': 'DROGAZILLE LTDA',
#   'ESTABELECIMENTO': 'DROGARIA ALVORADA',
#   'ENDERECO': 'RUA FLOR D AGUA, 375',
#   'BAIRRO': 'CASTELO',
#   'CIDADE': 'BELO HORIZONTE',
#   'UF': 'MG',
#   'CEP': '30810310',
#   'TELEFONE': '934181333',
#   'LATITUDE': -19.934549,
#   'LONGITUDE': -43.91724},
#  {'CNPJ': '20504144000273',
#   'RAZAO_SOCIAL': 'SUPER NOS SUPERMERCADOS LTDA',
#   'ESTABELECIMENTO': 'SUPER NOS',
#   'ENDERECO': 'RUA FLOR D AGUA, 572',
#   'BAIRRO': 'JARDIM ALVORADA',
#   'CIDADE': 'BELO HORIZONTE',
#   'UF': 'MG',
#   'CEP': '30810310',
#   'TELEFONE': None,
# ...

# %%
import polars as pl

dados = pl.DataFrame(base)
dados
# Out:
# shape: (4_000, 11)
# ┌───────────┬────────────┬────────────┬───────────┬───┬──────────┬───────────┬───────────┬─────────┐
# │ CNPJ      ┆ RAZAO_SOCI ┆ ESTABELECI ┆ ENDERECO  ┆ … ┆ CEP      ┆ TELEFONE  ┆ LATITUDE  ┆ LONGITU │
# │ ---       ┆ AL         ┆ MENTO      ┆ ---       ┆   ┆ ---      ┆ ---       ┆ ---       ┆ DE      │
# │ str       ┆ ---        ┆ ---        ┆ str       ┆   ┆ str      ┆ str       ┆ f64       ┆ ---     │
# │           ┆ str        ┆ str        ┆           ┆   ┆          ┆           ┆           ┆ f64     │
# ╞═══════════╪════════════╪════════════╪═══════════╪═══╪══════════╪═══════════╪═══════════╪═════════╡
# │ 188365380 ┆ MARILDA    ┆ CANTINA DA ┆ R POUSO   ┆ … ┆ 30240180 ┆ 986449681 ┆ -19.93463 ┆ -43.918 │
# │ 00104     ┆ MARTINS    ┆ MARILDA    ┆ ALTO, 727 ┆   ┆          ┆           ┆ 1         ┆ 32      │
# │           ┆ SILVA 9544 ┆            ┆           ┆   ┆          ┆           ┆           ┆         │
# ...
