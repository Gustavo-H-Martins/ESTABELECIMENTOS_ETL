# %%
from request_sodexo_api import get_establishments

base = get_establishments()
base
# Out:
# [{'ESTABELECIMENTO': 'BOASSA',
#   'RAZAO_SOCIAL': 'SINEZIO JANUARIO PEREIRA 21843265850',
#   'TELEFONE': '31 971094375 ',
#   'EMAIL': 'SINEZIOJANUARIO@HOTMAIL.COM',
#   'SITE': '',
#   'TIPO_LOGRADOURO': 'RUA',
#   'LOGRADOURO': 'PST DO MINERIO',
#   'NUMERO': '175',
#   'COMPLEMENTO': '',
#   'BAIRRO': 'POR DO SOL',
#   'CIDADE': 'LAGOA SANTA',
#   'ESTADO': 'MG',
#   'CEP': '33231050',
#   'LATITUDE': -19.644747,
#   'LONGITUDE': -43.90451059999,
#   'BANDEIRA': 'sodexo',
#   'LISTA_NEGRA': False},
#  {'ESTABELECIMENTO': 'CENTRAL RESTAURANTE E LANCHONETE',
#   'RAZAO_SOCIAL': 'ML COMERCIO DE ALIMENTOS LTDA',
#   'TELEFONE': '31 36815436',
#   'EMAIL': 'CENTRALRESTAURANTEELANCHONETE@GMAIL.COM',
#   'SITE': '',
#   'TIPO_LOGRADOURO': 'AVENIDA',
#   'LOGRADOURO': 'ACADEMICO NILO FIGUEIREDO',
#   'NUMERO': '2477',
#   'COMPLEMENTO': 'LJ 2',
#   'BAIRRO': 'JOANA DARC',
#   'CIDADE': 'LAGOA SANTA',
#   'ESTADO': 'MG',
#   'CEP': '33400000',
#   'LATITUDE': -19.6448815,
# ...

# %%
base[1]
# Out:
# {'_index': 'sodexo',
#  '_type': 'establishment',
#  '_id': '2249817',
#  '_score': None,
#  '_source': {'code': '2249817',
#   'fantasyname': 'CENTRAL RESTAURANTE E LANCHONETE',
#   'fantasynamesearch': 'centralrestauranteelanchonete',
#   'socialname': 'ML COMERCIO DE ALIMENTOS LTDA',
#   'webpage': '',
#   'phones': '31 36815436',
#   'email': 'CENTRALRESTAURANTEELANCHONETE@GMAIL.COM',
#   'addresssearch': 'lagoasantamg',
#   'place': 'AVENIDA',
#   'address': 'ACADEMICO NILO FIGUEIREDO',
#   'number': '2477',
#   'complement': 'LJ 2',
#   'town': 'JOANA DARC',
#   'city': 'LAGOA SANTA',
#   'state': 'MG',
#   'zipcode': '33400000',
#   'products': [{'code': '516',
#     'description': 'REFEICAO PASS CARTÃ\x83O',
#     'blacklist': False},
#    {'code': '526', 'description': 'ALIMENTACAO PASS', 'blacklist': False},
#    {'code': '5267',
#     'description': 'ALIMENTACAO PASS NATAL',
#     'blacklist': False}],
#   'location': {'lat': -19.6448815, 'lon': -43.9041845},
# ...
