# %%
from request_sodexo_api import get_establishments

base = get_establishments()
base
# Out:
# [{'CNPJ': None,
#   'RAZAO_SOCIAL': 'SINEZIO JANUARIO PEREIRA 21843265850',
#   'ESTABELECIMENTOS': 'BOASSA',
#   'ENDERECO': 'RUA PST DO MINERIO 175 ',
#   'BAIRRO': 'POR DO SOL',
#   'CIDADE': 'LAGOA SANTA',
#   'UF': 'MG',
#   'CEP': '33231050',
#   'EMAIL': 'SINEZIOJANUARIO@HOTMAIL.COM',
#   'TELEFONE': '31 971094375 ',
#   'LATITUDE': -19.644747,
#   'LONGITUDE': -43.90451059999,
#   'BANDEIRA': 'SODEXO'},
#  {'CNPJ': None,
#   'RAZAO_SOCIAL': 'ML COMERCIO DE ALIMENTOS LTDA',
#   'ESTABELECIMENTOS': 'CENTRAL RESTAURANTE E LANCHONETE',
#   'ENDERECO': 'AVENIDA ACADEMICO NILO FIGUEIREDO 2477 LJ 2',
#   'BAIRRO': 'JOANA DARC',
#   'CIDADE': 'LAGOA SANTA',
#   'UF': 'MG',
#   'CEP': '33400000',
#   'EMAIL': 'CENTRALRESTAURANTEELANCHONETE@GMAIL.COM',
#   'TELEFONE': '31 36815436',
#   'LATITUDE': -19.6448815,
#   'LONGITUDE': -43.9041845,
#   'BANDEIRA': 'SODEXO'},
#  {'CNPJ': None,
#   'RAZAO_SOCIAL': 'EUMACO COMERCIAL LTDA',
#   'ESTABELECIMENTOS': 'DECISAO ATACAREJO',
# ...

# %%
base[1]
