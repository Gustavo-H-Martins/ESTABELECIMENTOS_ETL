# %%
# libs
import pandas as pd
import warnings
import os
import sqlite3
import logging
warnings.filterwarnings('ignore')
pd.option_context(10,5)
from unidecode import unidecode

# %%
# define o caminho do diretório atual
current_dir = os.getcwd()
file_logs = current_dir.replace(r'sodexo\dados',r'logs\sodexo.log')
# configurando o registro de logs
logging.basicConfig(level=logging.DEBUG, filename=file_logs,encoding='utf-8', format="%(asctime)s - %(levelname)s - %(message)s")

# pega o arquivo gerado
base_sodexo = current_dir + r'\BASE_SODEXO.csv'
# carregada os dados no dataframe pandas aqui, simples né?

dados  = pd.read_csv(base_sodexo, sep=';', dtype='string')
dados
# Out:
#                                     RAZAO_SOCIAL
# 0                          HELCIAS ALMEIDA SOUSA  \
# 1                                HELBER A. SOUSA
# 2                        SERLATUR COMERCIAL LTDA
# 3                          GEOVANI COSTA ANDRADE
# 4                         I. TEIXEIRA FIGUEIREDO
# ...                                          ...
# 181550  ALVES BRANCO COMERCIO DE PRODUTOS ALIMEN
# 181551  ALVES CARDOSO COMERCIO DE PRODUTOS ALIME
# 181552           43.644.775 VIRLANE FRANCO SOUSA
# 181553  RAIZES GOIANA E MINEIRA RESTAURANTE LTDA
# 181554  PANIFICADORA E CONFEITARIA BONANZZA LTDA
#
#                           ESTABELECIMENTOS                           ENDERECO
# 0                            MERCADINHO HS         RUA NS SRA DAS GRACAS S/N   \
# 1                          COMERCIAL SOUZA                 RUA NS GRACAS 691
# 2                           SAGITARU'S MIX             RUA 15 DE NOVEMBRO SN
# 3                       PADARIA DO GEOVANI           TRECHO NS DE FATIMA 853
# 4                       COMERCIAL REI DAVI             RODOVIARIA PA 441 538
# ...                                    ...                                ...
# 181550                 REST. TUCANOS GRILL  RUA PREF CLS 4 BLOCO B 01 LOJA 03
# 181551           RESTAURANTE TUCANOS GRILL                  RUA CLS 4 BL B 1
# 181552                          DONNA FULO               RUA Q 205 01 LOJA 08
# 181553            RESTAURANTE FOGAO GOIANO                   RUA Q 205 01 02
# 181554  PANIFICADORA E CONFEITARIA BONANZA      RUA 8 8 CH 208 LT 02 LJ 01 02
#
#                     BAIRRO       CIDADE  UF       CEP       TELEFONE
# 0                   CENTRO  TERRA SANTA  PA  68285000   93 35381555   \
# 1                   CENTRO  TERRA SANTA  PA  68285000  93 992244793
# 2            SAO FRANCISCO  TERRA SANTA  PA  68285000    93 35381211
# 3              SANTA CLARA  TERRA SANTA  PA  68285000  93 991281988
# 4                CONQUISTA  TERRA SANTA  PA  68285000   93 99241585
# ...                    ...          ...  ..       ...            ...
# 181550      RIACHO FUNDO I     BRASILIA  DF  71820512   61 33990805
# 181551        RIACHO FUNDO     BRASILIA  DF  71820512    61 33998400
# 181552    SUL AGUAS CLARAS     BRASILIA  DF  71925000  61 995051888
# 181553    SUL AGUAS CLARAS     BRASILIA  DF  71925000    61 30211295
# 181554  SETOR HABITACIONAL     BRASILIA  DF  72006875   61 33977000
#
#                              EMAIL     LATITUDE    LONGITUDE BANDEIRA
# 0          HELCIAS_136@HOTMAIL.COM   -2.1094066  -56.4909992   SODEXO
# 1         HELBER_SOUSA@HOTMAIL.COM   -2.1100709  -56.4920171   SODEXO
# 2       LENAMACHADO_TS@HOTMAIL.COM   -2.1045525  -56.4881769   SODEXO
# 3       GEOVANEANDRADE12@GMAIL.COM    -2.101499  -56.4890777   SODEXO
# 4          SANYAROCHA224@GMAIL.COM    -2.102822  -56.4846757   SODEXO
# ...                            ...          ...          ...      ...
# 181550     RTUCANOSGRILL@GMAIL.COM  -15.8838908  -48.0158943   SODEXO
# 181551     ALVESBRANCO88@GMAIL.COM  -15.8837472  -48.0157542   SODEXO
# 181552   VIRLANEFRANCO21@GMAIL.COM  -15.8417157  -48.0208071   SODEXO
# 181553  ADMFOGAOGOIANO@HOTMAIL.COM  -15.8418923  -48.0204472   SODEXO
# 181554        BONANZAXML@GMAIL.COM  -15.8033432  -48.0387549   SODEXO
#
# [181555 rows x 12 columns]

# %%
dados['CIDADE'] = [unidecode(i) for i in dados['CIDADE'].map(str)]
dados['CIDADE'] = [i.replace('-', ' ') for i in dados['CIDADE'].map(str)]
dados
# Out:
#                                     RAZAO_SOCIAL
# 0                          HELCIAS ALMEIDA SOUSA  \
# 1                                HELBER A. SOUSA
# 2                        SERLATUR COMERCIAL LTDA
# 3                          GEOVANI COSTA ANDRADE
# 4                         I. TEIXEIRA FIGUEIREDO
# ...                                          ...
# 181550  ALVES BRANCO COMERCIO DE PRODUTOS ALIMEN
# 181551  ALVES CARDOSO COMERCIO DE PRODUTOS ALIME
# 181552           43.644.775 VIRLANE FRANCO SOUSA
# 181553  RAIZES GOIANA E MINEIRA RESTAURANTE LTDA
# 181554  PANIFICADORA E CONFEITARIA BONANZZA LTDA
#
#                           ESTABELECIMENTOS                           ENDERECO
# 0                            MERCADINHO HS         RUA NS SRA DAS GRACAS S/N   \
# 1                          COMERCIAL SOUZA                 RUA NS GRACAS 691
# 2                           SAGITARU'S MIX             RUA 15 DE NOVEMBRO SN
# 3                       PADARIA DO GEOVANI           TRECHO NS DE FATIMA 853
# 4                       COMERCIAL REI DAVI             RODOVIARIA PA 441 538
# ...                                    ...                                ...
# 181550                 REST. TUCANOS GRILL  RUA PREF CLS 4 BLOCO B 01 LOJA 03
# 181551           RESTAURANTE TUCANOS GRILL                  RUA CLS 4 BL B 1
# 181552                          DONNA FULO               RUA Q 205 01 LOJA 08
# 181553            RESTAURANTE FOGAO GOIANO                   RUA Q 205 01 02
# 181554  PANIFICADORA E CONFEITARIA BONANZA      RUA 8 8 CH 208 LT 02 LJ 01 02
#
#                     BAIRRO       CIDADE  UF       CEP       TELEFONE
# 0                   CENTRO  TERRA SANTA  PA  68285000   93 35381555   \
# 1                   CENTRO  TERRA SANTA  PA  68285000  93 992244793
# 2            SAO FRANCISCO  TERRA SANTA  PA  68285000    93 35381211
# 3              SANTA CLARA  TERRA SANTA  PA  68285000  93 991281988
# 4                CONQUISTA  TERRA SANTA  PA  68285000   93 99241585
# ...                    ...          ...  ..       ...            ...
# 181550      RIACHO FUNDO I     BRASILIA  DF  71820512   61 33990805
# 181551        RIACHO FUNDO     BRASILIA  DF  71820512    61 33998400
# 181552    SUL AGUAS CLARAS     BRASILIA  DF  71925000  61 995051888
# 181553    SUL AGUAS CLARAS     BRASILIA  DF  71925000    61 30211295
# 181554  SETOR HABITACIONAL     BRASILIA  DF  72006875   61 33977000
#
#                              EMAIL     LATITUDE    LONGITUDE BANDEIRA
# 0          HELCIAS_136@HOTMAIL.COM   -2.1094066  -56.4909992   SODEXO
# 1         HELBER_SOUSA@HOTMAIL.COM   -2.1100709  -56.4920171   SODEXO
# 2       LENAMACHADO_TS@HOTMAIL.COM   -2.1045525  -56.4881769   SODEXO
# 3       GEOVANEANDRADE12@GMAIL.COM    -2.101499  -56.4890777   SODEXO
# 4          SANYAROCHA224@GMAIL.COM    -2.102822  -56.4846757   SODEXO
# ...                            ...          ...          ...      ...
# 181550     RTUCANOSGRILL@GMAIL.COM  -15.8838908  -48.0158943   SODEXO
# 181551     ALVESBRANCO88@GMAIL.COM  -15.8837472  -48.0157542   SODEXO
# 181552   VIRLANEFRANCO21@GMAIL.COM  -15.8417157  -48.0208071   SODEXO
# 181553  ADMFOGAOGOIANO@HOTMAIL.COM  -15.8418923  -48.0204472   SODEXO
# 181554        BONANZAXML@GMAIL.COM  -15.8033432  -48.0387549   SODEXO
#
# [181555 rows x 12 columns]

# %%
# Salva tudo novamente desta vez com um csv e no banco de dados, a galera gosta de "variedades"
dados.to_csv(base_sodexo,sep=';', index=False, encoding='utf-8')
#Criar uma conexão com o banco de dados sqlite
db_file = current_dir.replace('sodexo\dados', r'app\files\database.db')
conn = sqlite3.connect(database=db_file)

#Converter o dataframe em uma tabela no banco de dados
"""
O parâmetro if_exists=`append` verifica se a tabela já existe e incrementa os dados
O parâmetro index=False evita que o índice do dataframe seja inserido na tabela
O parâmetro dtype define o tipo de cada coluna na tabela
"""
dados.to_sql('tb_sodexo', conn, 
             if_exists='replace', index=False, 
             dtype={'RAZAO_SOCIAL': 'TEXT', #PRIMARY KEY', 
                    'ESTABELECIMENTOS': 'TEXT', 'ENDERECO': 'TEXT', 
                    'BAIRRO': 'TEXT', 'CIDADE': 'TEXT', 'UF': 'TEXT', 
                    'CEP': 'TEXT', 'TELEFONE': 'TEXT', 
                    'EMAIL': 'TEXT', 'LATITUDE': 'TEXT', 
                    'LONGITUDE': 'TEXT', 'BANDEIRA': 'TEXT'})
# Finaliza a transação
conn.commit()
# Executa o comando VACUUM para compactar o banco de dados
conn.execute('VACUUM')

# Fechar a conexão com o banco de dados
conn.close()
